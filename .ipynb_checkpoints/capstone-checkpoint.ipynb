# %% [markdown]
# # Pytorch Capstone Project - Image Classification for detection of Diabetic Retinopathy
# This project involves building and training a Convolutional Neural Network model using Pytorch to detect Diabetic retinopathy based on images of retinas. The dataset used is from Indian Diabetic Retinopathy Image Dataset (IDRiD), which consists of 516 fundus images. This dataset is split into 413 training images and 103 testing images.
#
# The goal is to train the model to detect whether the image is indicative of diabetic retinopathy. Hence, this is a binary classification model, so it will make use of Pytorch's Binary Cross Entropy loss function to calculate weights. It also uses the Adam optimizer, with a learning rate of 0.0002.

# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

print(f'Available device: {device}')
# Out:
# Available device: cpu

# %%
training_csv_path = 'B. Disease Grading/B. Disease Grading/2. Groundtruths/a. IDRiD_Disease Grading_Training Labels.csv'
testing_csv_path = 'B. Disease Grading/B. Disease Grading/2. Groundtruths/b. IDRiD_Disease Grading_Testing Labels.csv'
root_disease_grading_path = 'B. Disease Grading/B. Disease Grading/'

training_images_path = 'B. Disease Grading/B. Disease Grading/1. Original Images/a. Training Set/'
testing_images_path = 'B. Disease Grading/B. Disease Grading/1. Original Images/b. Testing Set/'

# %%
class RetinalImageDataset(Dataset):
    def __init__(self, csv_df, images_path, transform=None, num_samples=None):
        """
        Args:
            csv_df (string): Dataframe from the csv file containing the data set
            transform (callable, optional): Optional transform to be applied on a sample
            num_samples (int, optional): Number of samples to load. If None, loads all samples
            images_path (string): Path to image set
        """
        self.csv_file = csv_df
        if num_samples is not None:
            self.csv_file = self.csv_file.head(num_samples)
        self.transform = transform
        self.images_path = images_path

    def __len__(self):
        return len(self.csv_file)

    def __getitem__(self, index):
        if torch.is_tensor(index):
            index = index.tolist()

        # Get image path and label
        img_path = self.images_path + self.csv_file.iloc[index, 0] + '.jpg'
        label = self.csv_file.iloc[index, 1]
        #print(f'Path: {img_path}, Label: {label}')

        # Load and convert the image
        image = Image.open(img_path)
        if image.mode != 'RGB':
            image = image.convert('RGB')
        if self.transform:
            image = self.transform(image)

        # Convert label to float
        label = torch.tensor(label, dtype=torch.float)

        return image, label

# %%
# Data Cleaning
training_csvfile = pd.read_csv(training_csv_path)
unnamed_columns = training_csvfile.columns[training_csvfile.columns.str.contains('Unnamed', case=False)]
training_csvfile = training_csvfile.drop(columns=unnamed_columns)

drop_columns = ['Retinopathy grade', 'Risk of macular edema ']

training_csvfile['Has Retinopathy'] = (training_csvfile['Retinopathy grade'] > 0).astype(int)
training_csvfile = training_csvfile.drop(columns=drop_columns)

testing_csvfile = pd.read_csv(testing_csv_path)
testing_csvfile['Has Retinopathy'] = (testing_csvfile['Retinopathy grade'] > 0).astype(int)
testing_csvfile = testing_csvfile.drop(columns=drop_columns)

print('Training\n', training_csvfile[185:195])
print('\nTesting\n',testing_csvfile[35:45])
# Out:
# Training
#      Image name  Has Retinopathy
# 185  IDRiD_186                1
# 186  IDRiD_187                1
# 187  IDRiD_188                1
# 188  IDRiD_189                1
# 189  IDRiD_190                0
# 190  IDRiD_191                1
# 191  IDRiD_192                1
# 192  IDRiD_193                0
# 193  IDRiD_194                1
# 194  IDRiD_195                0
#
# Testing
#     Image name  Has Retinopathy
# 35  IDRiD_036                1
# 36  IDRiD_037                0
# 37  IDRiD_038                0
# 38  IDRiD_039                0
# 39  IDRiD_040                1
# 40  IDRiD_041                0
# 41  IDRiD_042                1
# 42  IDRiD_043                0
# 43  IDRiD_044                0
# 44  IDRiD_045                0

# %% [markdown]
# ## Image Pre-processing and Augmentation
# The raw images will undergo pre-processing to ensure that the images are in a standardized format. This involves resizing them to a standard size, converting to PyTorch tensors, and normalizing the pixel values. All the images are resized to be 256x256.
#
# The raw images from the training set will additionally go through various random augmentations to provide variance within the images and allow the model to train with more diverse data. This should help prevent overfitting and improve generalization. The augmentations include randomly flipping the image horizontally and vertically, randomly rotating the image, adjusting various colour parameters like brightness, contrast, saturation, and hue, and finally, randomly changing the perspective of the image.

# %%
# Image Pre-Processing
train_transforms = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.RandomPerspective(0.02),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])   
])

val_and_testing_transforms = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])   
])

# %% [markdown]
# ## Splitting dataset into training and validation set
# The dataset is split into a training set and validation set in order to track the performance of the model. It is split such that 80% of the images are part of the training set, and 20% is a part of the validation set. This makes 331 images to train and 82 for validation.
#
# The image augmentations mentioned are done specifically to the training images, not the validation images.

# %%
# Load dataset
retinal_image_dataset = RetinalImageDataset(training_csvfile, training_images_path, transform=train_transforms)
train_size = 0.8
val_size = 0.2

train_dataset, _ = random_split(retinal_image_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))

retinal_image_dataset2 = RetinalImageDataset(training_csvfile, training_images_path, transform=val_and_testing_transforms)
train_size = 0.8
val_size = 0.2

_, val_dataset = random_split(retinal_image_dataset2, [train_size, val_size], generator=torch.Generator().manual_seed(42))

print(train_dataset.indices)
print(val_dataset.indices)
print(f'Size of training indices list: {len(train_dataset.indices)}')
print(f'Size of val indices list: {len(val_dataset.indices)}')
print(f'Common elements: {list(set(train_dataset.indices) & set(val_dataset.indices))}')
            

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)
print(f'Loading image from path: {training_images_path}')
print(f'Size of training set: {len(train_dataset)}')
print(f'Size of validation set: {len(val_dataset)}')
# Out:
# [64, 20, 234, 257, 282, 28, 196, 411, 183, 342, 261, 363, 310, 167, 50, 335, 122, 372, 135, 71, 96, 105, 4, 154, 141, 182, 73, 106, 240, 216, 302, 407, 24, 30, 339, 357, 296, 101, 45, 367, 278, 155, 397, 412, 92, 36, 56, 237, 391, 54, 272, 1, 100, 152, 85, 25, 153, 389, 136, 41, 148, 195, 406, 173, 32, 23, 322, 93, 264, 346, 109, 224, 81, 366, 360, 300, 14, 408, 126, 51, 33, 188, 376, 236, 354, 151, 192, 191, 393, 306, 158, 242, 356, 22, 231, 82, 169, 332, 319, 323, 204, 254, 142, 248, 9, 118, 210, 198, 338, 123, 97, 387, 405, 134, 111, 348, 253, 362, 57, 395, 286, 165, 127, 98, 328, 308, 355, 235, 13, 244, 214, 295, 341, 233, 159, 133, 379, 285, 107, 58, 181, 381, 119, 262, 287, 203, 340, 303, 276, 396, 258, 271, 368, 291, 139, 77, 114, 62, 293, 43, 345, 241, 207, 74, 222, 197, 263, 229, 410, 27, 171, 385, 277, 184, 175, 69, 382, 156, 301, 160, 53, 7, 117, 213, 337, 309, 40, 299, 384, 202, 162, 313, 369, 223, 140, 220, 290, 304, 209, 305, 267, 260, 365, 48, 294, 297, 76, 37, 55, 161, 112, 65, 380, 16, 70, 166, 199, 249, 61, 325, 163, 399, 5, 344, 143, 314, 121, 250, 358, 321, 347, 150, 243, 392, 238, 390, 279, 225, 378, 180, 170, 15, 186, 349, 115, 108, 86, 99, 280, 131, 364, 187, 94, 265, 333, 375, 164, 176, 284, 190, 95, 6, 78, 255, 185, 52, 316, 60, 283, 31, 79, 103, 80, 212, 218, 44, 67, 386, 189, 104, 87, 266, 221, 373, 383, 144, 259, 120, 273, 72, 129, 219, 89, 374, 211, 402, 157, 215, 83, 17, 298, 178, 145, 370, 311, 49, 201, 288, 63, 84, 318, 377, 327, 403, 3, 124, 239, 137, 21, 110, 247, 246, 138, 130, 359, 217, 281, 268, 125, 307, 113]
# [206, 226, 324, 409, 350, 274, 343, 388, 193, 256, 336, 351, 26, 251, 177, 38, 2, 331, 19, 292, 371, 315, 149, 361, 29, 42, 227, 116, 88, 146, 275, 35, 90, 320, 102, 34, 66, 232, 10, 270, 353, 317, 404, 352, 174, 228, 334, 179, 132, 398, 168, 394, 11, 0, 330, 172, 269, 46, 68, 289, 230, 8, 75, 147, 245, 12, 91, 39, 128, 400, 312, 194, 47, 252, 59, 401, 329, 200, 18, 326, 208, 205]
# Size of training indices list: 331
# Size of val indices list: 82
# Common elements: []
# Loading image from path: B. Disease Grading/B. Disease Grading/1. Original Images/a. Training Set/
# Size of training set: 331
# Size of validation set: 82

# %% [markdown]
# ## Convolutional Neural Network architecture
# This neural network consists of three convolutional layers consisting of a 3x3 kernel with padding. A 2x2 max-pooling kernel is used after each convolution layer to reduce the dimentionality while retaining important information. The output of the last max-pooling layer is sent to two fully connected layers. Each of the layers uses the ReLU activation function, except the final layer, which uses sigmoid function.

# %%
# Convolutional Neural Network architecture

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 48, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(48, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        
        self.fc1 = nn.Linear(128 * 32 * 32, 256)
        self.fc2 = nn.Linear(256, 1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)

        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = torch.sigmoid(self.fc2(x)).squeeze(1)
        return x

cnn_model = CNN()
cnn_model = cnn_model.to(device)

# %% [markdown]
# ## Training the model
# The model uses the Binary Cross Entropy loss function and the Adam optimizer, with a learning rate of 0.0002. The training and validation loop runs for five epochs, and the training and validation losses are tracked and graphed visually to see how it performs over all the epochs.

# %%
# Initialize loss function and optimizers
criterion = nn.BCELoss()
optimizer = optim.Adam(cnn_model.parameters(), lr=0.0002)

# %%
# Training and Validation Loop
num_epochs = 5
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    total_train_loss = 0
    total_val_loss = 0

    # Training
    cnn_model.train()
    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = cnn_model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()
    train_losses.append(total_train_loss / len(train_dataloader))

    # Validation
    cnn_model.eval()
    with torch.no_grad():
        for images, labels in val_dataloader:
            images, labels = images.to(device), labels.to(device)
            val_outputs = cnn_model(images)
            val_loss = criterion(val_outputs, labels)
            total_val_loss += val_loss.item()
        val_losses.append(total_val_loss / len(val_dataloader))
    
    # Print Epochs and loss information
    print(f'Epoch: [{epoch + 1}/{num_epochs}], Training Loss: {total_train_loss / len(train_dataloader)} , Validation Loss: {total_val_loss / len(val_dataloader)}')
# Out:
# Epoch: [1/5], Training Loss: 0.6763913197950884 , Validation Loss: 0.5797790288925171
# Epoch: [2/5], Training Loss: 0.6317149834199385 , Validation Loss: 0.5648440718650818
# Epoch: [3/5], Training Loss: 0.5997837077487599 , Validation Loss: 0.5535914798577627
# Epoch: [4/5], Training Loss: 0.5994596481323242 , Validation Loss: 0.5357013742129008
# Epoch: [5/5], Training Loss: 0.5846819335764105 , Validation Loss: 0.5453426738580068

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, label='Training Loss', marker='o')
plt.plot(epochs, val_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Testing the model
# Load the testing data set

test_dataset = RetinalImageDataset(testing_csvfile, testing_images_path, transform=val_and_testing_transforms)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
test_pred_probs = []
test_pred_labels = []
test_true_labels = []

with torch.no_grad():
    for images, labels in test_dataloader:
        images, labels = images.to(device), labels.to(device)
        outputs = cnn_model(images)

        test_pred_probs.extend(outputs.cpu().numpy())

        pred_labels = torch.round(outputs)
        test_pred_labels.extend(pred_labels.cpu().numpy())

        test_true_labels.extend(labels.cpu().numpy())

test_pred_probs = np.array(test_pred_probs)
test_pred_labels = np.array(test_pred_labels)
test_true_labels = np.array(test_true_labels)

for i in range(103):
    print(f'Predicted Probablity:{test_pred_probs[i]}, Predicted Label:{test_pred_labels[i]}, Actual Label:{test_true_labels[i]}')
# Out:
# Predicted Probablity:0.4233883321285248, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.508712112903595, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6705834865570068, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.47395315766334534, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.42476168274879456, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.5582166314125061, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7602587342262268, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7072979211807251, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6951262354850769, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4976441264152527, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.4515092670917511, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.7419331669807434, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8473050594329834, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8796481490135193, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6894015669822693, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7434050440788269, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4278915226459503, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.6538506746292114, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.742621123790741, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7354384064674377, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8522655963897705, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8390491604804993, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4404219090938568, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.6996413469314575, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7783315181732178, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8020172715187073, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.790588915348053, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6458361148834229, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6094339489936829, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6282221078872681, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6840914487838745, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6517669558525085, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.709391713142395, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6929544806480408, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6968189477920532, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.743858814239502, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6946543455123901, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6973295211791992, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6889148950576782, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7812268733978271, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6350505948066711, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.8063516616821289, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.697810173034668, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6008537411689758, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7128174304962158, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7820291519165039, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6442292928695679, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6180354952812195, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4339545667171478, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.7114139795303345, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.4389638602733612, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.7875652313232422, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7407010197639465, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7699571847915649, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7276664972305298, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6186848878860474, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6463853716850281, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6396017670631409, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7462629675865173, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6279001235961914, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7466285824775696, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7813915014266968, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.5416810512542725, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7266541719436646, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7798238396644592, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.5319949984550476, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7642163038253784, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7689118981361389, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.668726921081543, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5815336108207703, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.43887782096862793, Predicted Label:0.0, Actual Label:0.0
# Predicted Probablity:0.7899770736694336, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6600899696350098, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6442965269088745, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7719006538391113, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.4738520681858063, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.5659831762313843, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7241520881652832, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6882484555244446, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.5883699655532837, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.8330580592155457, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.662809431552887, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.843465268611908, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.47042298316955566, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.7596299052238464, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7016507387161255, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7481651902198792, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6958245038986206, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6734494566917419, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.570019006729126, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7025034427642822, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.42641937732696533, Predicted Label:0.0, Actual Label:0.0
# Predicted Probablity:0.626512885093689, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6872680187225342, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5637422800064087, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.704077422618866, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5515233278274536, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.42300012707710266, Predicted Label:0.0, Actual Label:0.0
# Predicted Probablity:0.6875177621841431, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6955870389938354, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6873649954795837, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8659616708755493, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7013496160507202, Predicted Label:1.0, Actual Label:0.0

# %%
from sklearn.metrics import classification_report

classes = ['Has retinopathy', 'Does not have retinopathy']

report = classification_report(test_true_labels, test_pred_labels, target_names=classes)

print(report)
# Out:
#                            precision    recall  f1-score   support
#
#           Has retinopathy       0.21      0.09      0.12        34
# Does not have retinopathy       0.65      0.84      0.73        69
#
#                  accuracy                           0.59       103
#                 macro avg       0.43      0.46      0.43       103
#              weighted avg       0.51      0.59      0.53       103

# %% [markdown]
# ## Results
# We see that based on our CNN model, the model has an accuracy score of 59%. The model performs quite well when it comes to detecting if an image indicates it does not have retinopathy. However, it struggles to accurately detect images that indicates retinopathy. Some ways to combat this may be to use a much larger dataset, preprocessing the data further to improve variance and remove noise, or modifying the model with different number of hidden layers and neurons.

# %% [markdown]
# ## VGG-16 Convolutional Neural Network Model
# VGG-16 is a Convolutional Neural Network Model that is proposed by Karen Simonyan and Andrew Zisserman from the Visual Geometry Group at University of Oxford. It is designed for training large scale models for image classification tasks. While it is best used for larger datasets, I wanted to try an implement it to see how it performs with this IDRiD dataset.
#
# ## VGG-16 Architecture and implementation
# VGG-16 consists of a total of 16 layers, of which there are 13 convolutional layers, and 3 fully connected layers. The convolutional layers have a kernel size of 3x3 and a padding of 1. There are 2 sets of convolutional layers having 64 output channels, 2 sets with 128 output channels, 3 sets with 256 output channels, and 6 sets with 512 output channels.
#
# There are also 5 max-pooling layers with a kernel size of 2x2, and a stride of 2. Each of these pooling layers come after each of the sets, and one of them in the middle of the sets with 512 output channels.
#
# The output of the final pooling layer is flattened and sent to three fully connected linear layers. Two of them have an output size of 4096. For this specific binary classification task, the final layer has an output of 1.
#
# All of these channels are given the ReLU activation function, except the last one, which uses the sigmoid function.

# %%
# Training with a CNN model based on VGG-16

class VGG_16_CNN(nn.Module):
    def __init__(self):
        super(VGG_16_CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(128)

        self.conv5 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(256)
        self.conv6 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(256)
        self.conv7 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.bn7 = nn.BatchNorm2d(256)

        self.conv8 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn8 = nn.BatchNorm2d(512)
        self.conv9 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.bn9 = nn.BatchNorm2d(512)
        self.conv10 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.bn10 = nn.BatchNorm2d(512)
        
        self.conv11 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.bn11 = nn.BatchNorm2d(512)
        self.conv12 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.bn12 = nn.BatchNorm2d(512)
        self.conv13 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.bn13 = nn.BatchNorm2d(512)
        
        self.fc1 = nn.Linear(512 * 8 * 8, 4096)
        self.bn_fc1 = nn.BatchNorm1d(4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.bn_fc2 = nn.BatchNorm1d(4096)
        self.fc3 = nn.Linear(4096, 1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))
        x = F.relu(self.bn7(self.conv7(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn8(self.conv8(x)))
        x = F.relu(self.bn9(self.conv9(x)))
        x = F.relu(self.bn10(self.conv10(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn11(self.conv11(x)))
        x = F.relu(self.bn12(self.conv12(x)))
        x = F.relu(self.bn13(self.conv13(x)))
        x = F.max_pool2d(x, 2)

        x = x.view(x.size(0), -1)

        x = F.relu(self.bn_fc1(self.fc1(x)))
        x = F.relu(self.bn_fc2(self.fc2(x)))
        x = torch.sigmoid(self.fc3(x)).squeeze(1)
        return x

vgg_16_cnn_model = VGG_16_CNN()
vgg_16_cnn_model = vgg_16_cnn_model.to(device)

# %%
# Initialize loss function and optimizers
criterion = nn.BCELoss()
optimizer = optim.Adam(vgg_16_cnn_model.parameters(), lr=0.002, weight_decay=1e-4)

print(len(val_dataloader))
# Out:
# 3

# %%
# Training and Validation Loop
num_epochs = 3
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    total_train_loss = 0
    total_val_loss = 0

    # Training
    vgg_16_cnn_model.train()
    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = vgg_16_cnn_model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()
    train_losses.append(total_train_loss / len(train_dataloader))

    # Validation
    vgg_16_cnn_model.eval()
    with torch.no_grad():
        for images, labels in val_dataloader:
            images, labels = images.to(device), labels.to(device)
            val_outputs = vgg_16_cnn_model(images)
            val_loss = criterion(val_outputs, labels)
            total_val_loss += val_loss.item()
        val_losses.append(total_val_loss / len(val_dataloader))
    
    # Print Epochs and loss information
    print(f'Epoch: [{epoch + 1}/{num_epochs}], Training Loss: {total_train_loss / len(train_dataloader)} , Validation Loss: {total_val_loss / len(val_dataloader)}')
# Out:
# Epoch: [1/3], Training Loss: 1.5057152672247454 , Validation Loss: 28.472222010294598
# Epoch: [2/3], Training Loss: 0.7298836437138644 , Validation Loss: 7.395933508872986
# Epoch: [3/3], Training Loss: 0.7687502015720714 , Validation Loss: 0.9600446621576945

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, label='Training Loss', marker='o')
plt.plot(epochs, val_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses Over Epochs (VGG-16)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Testing the model
# Load the testing data set

test_dataset = RetinalImageDataset(testing_csvfile, testing_images_path, transform=val_and_testing_transforms)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
test_pred_probs = []
test_pred_labels = []
test_true_labels = []

with torch.no_grad():
    for images, labels in test_dataloader:
        images, labels = images.to(device), labels.to(device)
        outputs = vgg_16_cnn_model(images)

        test_pred_probs.extend(outputs.cpu().numpy())

        pred_labels = torch.round(outputs)
        test_pred_labels.extend(pred_labels.cpu().numpy())

        test_true_labels.extend(labels.cpu().numpy())

test_pred_probs = np.array(test_pred_probs)
test_pred_labels = np.array(test_pred_labels)
test_true_labels = np.array(test_true_labels)

for i in range(103):
    print(f'Predicted Probablity:{test_pred_probs[i]}, Predicted Label:{test_pred_labels[i]}, Actual Label:{test_true_labels[i]}')
# Out:
# Predicted Probablity:0.7177348732948303, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7186819314956665, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7205023169517517, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.674045979976654, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6377441883087158, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.46491843461990356, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.7211012244224548, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6460163593292236, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7124979496002197, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7307126522064209, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6646422743797302, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6232581734657288, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.618398129940033, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6846657991409302, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7208772897720337, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7229608297348022, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7201047539710999, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7988351583480835, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6900696754455566, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7590142488479614, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6195521354675293, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.5006207823753357, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6143887042999268, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.723392128944397, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7646718621253967, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6349326372146606, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.9896309971809387, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.9386305809020996, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.974492609500885, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.8137943744659424, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6671940684318542, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7975393533706665, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6336880922317505, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7458836436271667, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8422200083732605, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8933786749839783, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6631259322166443, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7228747010231018, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7185327410697937, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5479230284690857, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8783742189407349, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7141921520233154, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.9361703991889954, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7879773378372192, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6059051752090454, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.9721602201461792, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7418975830078125, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7842279076576233, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8674454689025879, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6028634905815125, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7177311778068542, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6032913327217102, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6433574557304382, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.9890193343162537, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7193479537963867, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.9460651278495789, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5929434299468994, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7216681241989136, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7152510285377502, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7092781662940979, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4858541488647461, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.5899218320846558, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.9703000783920288, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4607871472835541, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.574173629283905, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6962334513664246, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7181410193443298, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.683297336101532, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7222882509231567, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.9227234721183777, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6110125780105591, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7162759304046631, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.723545491695404, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7189058661460876, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.5946952104568481, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6272669434547424, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8433869481086731, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6403273940086365, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5880665183067322, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7599983811378479, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.600365936756134, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7206389904022217, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6527035236358643, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7129186987876892, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.4688307046890259, Predicted Label:0.0, Actual Label:1.0
# Predicted Probablity:0.6247522830963135, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.511713445186615, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7362185120582581, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.6186231374740601, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.8192098140716553, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5819078087806702, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.7175799012184143, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7234325408935547, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.5923147797584534, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.8673068881034851, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6082091927528381, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6842694282531738, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7163139581680298, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.7918597459793091, Predicted Label:1.0, Actual Label:0.0
# Predicted Probablity:0.6008021831512451, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.5214685201644897, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.9185647368431091, Predicted Label:1.0, Actual Label:1.0
# Predicted Probablity:0.645439624786377, Predicted Label:1.0, Actual Label:0.0

# %%
from sklearn.metrics import classification_report

classes = ['Has retinopathy', 'Does not have retinopathy']

report = classification_report(test_true_labels, test_pred_labels, target_names=classes)

print(report)
# Out:
#                            precision    recall  f1-score   support
#
#           Has retinopathy       0.00      0.00      0.00        34
# Does not have retinopathy       0.66      0.94      0.77        69
#
#                  accuracy                           0.63       103
#                 macro avg       0.33      0.47      0.39       103
#              weighted avg       0.44      0.63      0.52       103
